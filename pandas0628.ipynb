# %% [markdown]
# # 판다스 10분 완성
# ## 1.Object Creation (객체 생성)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365
# 2013-01-06 -0.171845  1.194779  0.289561  0.563102

# %%
df2 = pd.DataFrame({'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)), dtype='float32'),
                    'D' : np.array([3]*4, dtype='int32'),
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ## 2. Viewing Data (데이터 확인하기)

# %%
df.tail(3) # 끝에서 마지막 3줄을 불러옴
# Out:
#                    A         B         C         D
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365
# 2013-01-06 -0.171845  1.194779  0.289561  0.563102

# %%
df.tail() # 끝에서 마지막 5줄 불러옴
# Out:
#                    A         B         C         D
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365
# 2013-01-06 -0.171845  1.194779  0.289561  0.563102

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.53716808, -1.52293994,  0.83119534,  3.56067665],
#        [-1.41760691,  0.74013831, -0.30593316,  0.79045842],
#        [-0.82676805, -0.32656947, -0.69089334, -0.24781903],
#        [ 0.18972719, -0.95691494, -1.69870345,  1.69217468],
#        [-0.0418464 ,  0.34649156,  0.50830366, -1.66936518],
#        [-0.17184456,  1.19477948,  0.28956138,  0.56310241]])

# %%
df.describe() #통계적 정보요약
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.288528 -0.087503 -0.177745  0.781538
# std    0.714071  1.038374  0.927369  1.770151
# min   -1.417607 -1.522940 -1.698703 -1.669365
# 25%   -0.663037 -0.799329 -0.594653 -0.045089
# 50%   -0.106845  0.009961 -0.008186  0.676780
# 75%    0.131834  0.641727  0.453618  1.466746
# max    0.537168  1.194779  0.831195  3.560677

# %%
df.T #데이터를 전치
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.537168   -1.417607   -0.826768    0.189727   -0.041846   -0.171845
# B   -1.522940    0.740138   -0.326569   -0.956915    0.346492    1.194779
# C    0.831195   -0.305933   -0.690893   -1.698703    0.508304    0.289561
# D    3.560677    0.790458   -0.247819    1.692175   -1.669365    0.563102

# %%
df.sort_index(axis=1, ascending=False) #축 별로 정렬
# Out:
#                    D         C         B         A
# 2013-01-01  3.560677  0.831195 -1.522940  0.537168
# 2013-01-02  0.790458 -0.305933  0.740138 -1.417607
# 2013-01-03 -0.247819 -0.690893 -0.326569 -0.826768
# 2013-01-04  1.692175 -1.698703 -0.956915  0.189727
# 2013-01-05 -1.669365  0.508304  0.346492 -0.041846
# 2013-01-06  0.563102  0.289561  1.194779 -0.171845

# %%
df.sort_values(by='B') #값 별로 정렬
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-06 -0.171845  1.194779  0.289561  0.563102

# %% [markdown]
# ## 3. Selection (선택)
# - Getting (데이터 얻기)

# %%
df['A']
# Out:
# 2013-01-01    0.537168
# 2013-01-02   -1.417607
# 2013-01-03   -0.826768
# 2013-01-04    0.189727
# 2013-01-05   -0.041846
# 2013-01-06   -0.171845
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175

# %% [markdown]
# - Selection by Label (Label 을 통한 선택)

# %%
df.loc[dates[0]]
# Out:
# A    0.537168
# B   -1.522940
# C    0.831195
# D    3.560677
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01  0.537168 -1.522940
# 2013-01-02 -1.417607  0.740138
# 2013-01-03 -0.826768 -0.326569
# 2013-01-04  0.189727 -0.956915
# 2013-01-05 -0.041846  0.346492
# 2013-01-06 -0.171845  1.194779

# %%
df.loc['20130102':'20130104', ['A','B']]
# Out:
#                    A         B
# 2013-01-02 -1.417607  0.740138
# 2013-01-03 -0.826768 -0.326569
# 2013-01-04  0.189727 -0.956915

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -1.417607
# B    0.740138
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 0.5371680822425628

# %%
df.at[dates[0],'A']
# Out:
# 0.5371680822425628

# %% [markdown]
# - Selection by Position (위치로 선택하기)

# %%
df.iloc[3]
# Out:
# A    0.189727
# B   -0.956915
# C   -1.698703
# D    1.692175
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  0.189727 -0.956915
# 2013-01-05 -0.041846  0.346492

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -1.417607 -0.305933
# 2013-01-03 -0.826768 -0.690893
# 2013-01-05 -0.041846  0.508304

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -1.522940  0.831195
# 2013-01-02  0.740138 -0.305933
# 2013-01-03 -0.326569 -0.690893
# 2013-01-04 -0.956915 -1.698703
# 2013-01-05  0.346492  0.508304
# 2013-01-06  1.194779  0.289561

# %%
df.iloc[1,1]
# Out:
# 0.7401383124245268

# %%
df.iat[1,1]
# Out:
# 0.7401383124245268

# %% [markdown]
# - Boolean Indexing

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.537168       NaN  0.831195  3.560677
# 2013-01-02       NaN  0.740138       NaN  0.790458
# 2013-01-03       NaN       NaN       NaN       NaN
# 2013-01-04  0.189727       NaN       NaN  1.692175
# 2013-01-05       NaN  0.346492  0.508304       NaN
# 2013-01-06       NaN  1.194779  0.289561  0.563102

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.537168 -1.522940  0.831195  3.560677    one
# 2013-01-02 -1.417607  0.740138 -0.305933  0.790458    one
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819    two
# 2013-01-04  0.189727 -0.956915 -1.698703  1.692175  three
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365   four
# 2013-01-06 -0.171845  1.194779  0.289561  0.563102  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.826768 -0.326569 -0.690893 -0.247819   two
# 2013-01-05 -0.041846  0.346492  0.508304 -1.669365  four

# %% [markdown]
# - Setting (설정)

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
df.at[dates[0],'A'] = 0
df.iat[0,1] = 0
df.loc[:,'D'] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.831195  5  NaN
# 2013-01-02 -1.417607  0.740138 -0.305933  5  1.0
# 2013-01-03 -0.826768 -0.326569 -0.690893  5  2.0
# 2013-01-04  0.189727 -0.956915 -1.698703  5  3.0
# 2013-01-05 -0.041846  0.346492  0.508304  5  4.0
# 2013-01-06 -0.171845  1.194779  0.289561  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.831195 -5  NaN
# 2013-01-02 -1.417607 -0.740138 -0.305933 -5 -1.0
# 2013-01-03 -0.826768 -0.326569 -0.690893 -5 -2.0
# 2013-01-04 -0.189727 -0.956915 -1.698703 -5 -3.0
# 2013-01-05 -0.041846 -0.346492 -0.508304 -5 -4.0
# 2013-01-06 -0.171845 -1.194779 -0.289561 -5 -5.0

# %% [markdown]
# ## 4. Missing Data (결측치)

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.831195  5  NaN  1.0
# 2013-01-02 -1.417607  0.740138 -0.305933  5  1.0  1.0
# 2013-01-03 -0.826768 -0.326569 -0.690893  5  2.0  NaN
# 2013-01-04  0.189727 -0.956915 -1.698703  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -1.417607  0.740138 -0.305933  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.831195  5  5.0  1.0
# 2013-01-02 -1.417607  0.740138 -0.305933  5  1.0  1.0
# 2013-01-03 -0.826768 -0.326569 -0.690893  5  2.0  5.0
# 2013-01-04  0.189727 -0.956915 -1.698703  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## 5. Operation (연산)
# - Stats (통계)

# %%
df.mean()
# Out:
# A   -0.378056
# B    0.166321
# C   -0.177745
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.457799
# 2013-01-02    1.003320
# 2013-01-03    1.031154
# 2013-01-04    1.106822
# 2013-01-05    1.962590
# 2013-01-06    2.262499
# Freq: D, dtype: float64

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.826768 -1.326569 -1.690893  4.0  1.0
# 2013-01-04 -2.810273 -3.956915 -4.698703  2.0  0.0
# 2013-01-05 -5.041846 -4.653508 -4.491696  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# - Apply (적용)

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.831195   5   NaN
# 2013-01-02 -1.417607  0.740138  0.525262  10   1.0
# 2013-01-03 -2.244375  0.413569 -0.165631  15   3.0
# 2013-01-04 -2.054648 -0.543346 -1.864335  20   6.0
# 2013-01-05 -2.096494 -0.196855 -1.356031  25  10.0
# 2013-01-06 -2.268339  0.997925 -1.066470  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.607334
# B    2.151694
# C    2.529899
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# - Histogramming (히스토그래밍)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# 4    2
# 5    1
# 6    5
# 7    2
# 8    3
# 9    5
# dtype: int64

# %%
s.value_counts()
# Out:
# 2    4
# 1    2
# 3    2
# 5    2
# dtype: int64

# %% [markdown]
# - String Methods (문자열 메소드)

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## 6. Merge (병합)
# - Concat (연결)

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.300270  0.644198 -1.168628  2.038951
# 1 -1.626040  1.935020 -0.762870  0.360284
# 2 -1.674853  0.617954  0.766726  0.374496
# 3 -0.521029  1.424285 -0.447041  3.092677
# 4  0.268678 -1.001392  1.729981 -0.126541
# 5  0.212906 -0.141208 -0.968353 -0.626213
# 6 -1.735526 -0.583301 -0.132652  0.771896
# 7 -0.009821  0.127725  2.808065 -1.154641
# 8  2.961907  1.781734 -1.616500 -0.048640
# 9 -0.020551 -0.354377 -0.936459  1.003333

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.300270  0.644198 -1.168628  2.038951
# 1 -1.626040  1.935020 -0.762870  0.360284
# 2 -1.674853  0.617954  0.766726  0.374496
# 3 -0.521029  1.424285 -0.447041  3.092677
# 4  0.268678 -1.001392  1.729981 -0.126541
# 5  0.212906 -0.141208 -0.968353 -0.626213
# 6 -1.735526 -0.583301 -0.132652  0.771896
# 7 -0.009821  0.127725  2.808065 -1.154641
# 8  2.961907  1.781734 -1.616500 -0.048640
# 9 -0.020551 -0.354377 -0.936459  1.003333

# %% [markdown]
# - Join (결합)

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on= 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key' : ['foo', 'bar'], 'lval' : [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on= 'key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# - Append (추가)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  1.065364  1.053500 -0.259130  0.812456
# 1  0.903536 -1.343285  0.522866  0.038905
# 2  0.745448 -2.741287  0.029608 -0.298409
# 3  1.048641  0.061178  0.401796  1.644205
# 4 -0.436193 -2.357151 -2.436356  0.962288
# 5  1.234701  1.770005 -0.102564 -0.004561
# 6  0.070735 -0.988170 -0.917713 -0.266052
# 7 -0.901988 -0.290211  1.398146  0.605998

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  1.065364  1.053500 -0.259130  0.812456
# 1  0.903536 -1.343285  0.522866  0.038905
# 2  0.745448 -2.741287  0.029608 -0.298409
# 3  1.048641  0.061178  0.401796  1.644205
# 4 -0.436193 -2.357151 -2.436356  0.962288
# 5  1.234701  1.770005 -0.102564 -0.004561
# 6  0.070735 -0.988170 -0.917713 -0.266052
# 7 -0.901988 -0.290211  1.398146  0.605998
# 8  1.048641  0.061178  0.401796  1.644205

# %% [markdown]
# ## 7. Grouping (그룹화)

# %%
df = pd.DataFrame(
    {
        'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C' : np.random.randn(8),
        'D' : np.random.randn(8)
    })
df
# Out:
#      A      B         C         D
# 0  foo    one -1.753517 -0.636300
# 1  bar    one  0.691673  0.438460
# 2  foo    two -0.481799  0.583336
# 3  bar  three  0.362088 -0.469820
# 4  foo    two -0.709548  0.213033
# 5  bar    two -0.825493 -0.485064
# 6  foo    one  0.538008 -0.181902
# 7  foo  three  0.396394 -0.512129

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.228268 -0.516424
# foo -2.010462 -0.533962

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.691673  0.438460
#     three  0.362088 -0.469820
#     two   -0.825493 -0.485064
# foo one   -1.215509 -0.818202
#     three  0.396394 -0.512129
#     two   -1.191347  0.796369

# %% [markdown]
# ## 8. Reshaping (변형)
# - Stack (스택)

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                     'foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2  =  df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.587551 -0.258143
#       two     1.069153 -1.227421
# baz   one    -0.932617 -1.803034
#       two    -0.864412  0.169032

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.587551
#                B   -0.258143
#        two     A    1.069153
#                B   -1.227421
# baz    one     A   -0.932617
#                B   -1.803034
#        two     A   -0.864412
#                B    0.169032
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.587551 -0.258143
#       two     1.069153 -1.227421
# baz   one    -0.932617 -1.803034
#       two    -0.864412  0.169032

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.587551  1.069153
#       B -0.258143 -1.227421
# baz   A -0.932617 -0.864412
#       B -1.803034  0.169032

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.587551 -0.932617
#        B -0.258143 -1.803034
# two    A  1.069153 -0.864412
#        B -1.227421  0.169032

# %% [markdown]
# - Pivot Tables (피봇 테이블)

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                   'B' : ['A', 'B', 'C'] * 4,
                   'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D' : np.random.randn(12),
                   'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.008544  0.066193
# 1     one  B  foo -1.888534  1.171839
# 2     two  C  foo -0.559295 -0.347379
# 3   three  A  bar  0.119000 -1.933586
# 4     one  B  bar -1.210511 -1.450005
# 5     one  C  bar  1.396688 -0.100705
# 6     two  A  foo  0.462521  2.410280
# 7   three  B  foo  1.129052 -0.574137
# 8     one  C  foo -0.721876 -1.295897
# 9     one  A  bar -0.742471 -0.455366
# 10    two  B  bar  0.240881  0.612598
# 11  three  C  bar -0.372476  0.609670

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.742471 -0.008544
#       B -1.210511 -1.888534
#       C  1.396688 -0.721876
# three A  0.119000       NaN
#       B       NaN  1.129052
#       C -0.372476       NaN
# two   A       NaN  0.462521
#       B  0.240881       NaN
#       C       NaN -0.559295

# %% [markdown]
# ## 9. Time Series (시계열)

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25084
# Freq: 5T, dtype: int64

# %% [markdown]
# - 시간대를 표현

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -1.252587
# 2012-03-07   -1.408224
# 2012-03-08   -0.783360
# 2012-03-09    0.179657
# 2012-03-10    0.094302
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -1.252587
# 2012-03-07 00:00:00+00:00   -1.408224
# 2012-03-08 00:00:00+00:00   -0.783360
# 2012-03-09 00:00:00+00:00    0.179657
# 2012-03-10 00:00:00+00:00    0.094302
# Freq: D, dtype: float64

# %% [markdown]
# - 다른 시간대로 변환

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -1.252587
# 2012-03-06 19:00:00-05:00   -1.408224
# 2012-03-07 19:00:00-05:00   -0.783360
# 2012-03-08 19:00:00-05:00    0.179657
# 2012-03-09 19:00:00-05:00    0.094302
# Freq: D, dtype: float64

# %% [markdown]
# - 시간 표현 ↔ 기간 표현으로 변환

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -0.485743
# 2012-02-29    1.980416
# 2012-03-31   -0.520892
# 2012-04-30   -0.028493
# 2012-05-31   -0.194479
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01   -0.485743
# 2012-02    1.980416
# 2012-03   -0.520892
# 2012-04   -0.028493
# 2012-05   -0.194479
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.485743
# 2012-02-01    1.980416
# 2012-03-01   -0.520892
# 2012-04-01   -0.028493
# 2012-05-01   -0.194479
# Freq: MS, dtype: float64

# %% [markdown]
# - 기간 ↔ 시간 변환은 편리한 산술 기능들을 사용할 수 있도록 만들어줍니다. 다음 예제에서, 우리는 11월에 끝나는 연말 결산의 분기별 빈도를 분기말 익월의 월말일 오전 9시로 변환합니다.

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    0.487662
# 1990-06-01 09:00   -0.810018
# 1990-09-01 09:00    0.563653
# 1990-12-01 09:00    1.285432
# 1991-03-01 09:00   -0.730408
# Freq: H, dtype: float64

# %% [markdown]
# ## 10. Categoricals (범주화)

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %%
# 가공하지 않은 성적을 범주형 데이터로 변환
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# 범주에 더 의미 있는 이름을 붙인다
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## 11. Plotting (그래프)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## 12. Getting Data In / Out (데이터 입 / 출력)
#
# - CSV

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01   1.144381  -0.002242   0.158862  -0.240616
# 1    2000-01-02   0.384763   0.033501   1.638435  -1.486811
# 2    2000-01-03   0.504765  -1.198235   2.955597  -1.257166
# 3    2000-01-04   0.803148  -1.282076   5.966986  -2.501552
# 4    2000-01-05   1.023462  -0.844092   5.671452  -2.672713
# ..          ...        ...        ...        ...        ...
# 995  2002-09-22  34.205367 -50.416431 -41.939157 -28.881550
# 996  2002-09-23  34.047809 -50.561633 -40.745521 -31.034942
# 997  2002-09-24  34.394324 -50.846630 -40.560689 -30.859070
# 998  2002-09-25  33.374786 -49.925112 -40.039959 -31.770444
# 999  2002-09-26  32.796673 -50.321773 -39.319165 -31.097754
#
# [1000 rows x 5 columns]

# %% [markdown]
# - HDF5

# %%
df.to_hdf('foo.h5','df')

# %%
pd.read_hdf('foo.h5','df')
# Out:
#                     A          B          C          D
# 2000-01-01   1.144381  -0.002242   0.158862  -0.240616
# 2000-01-02   0.384763   0.033501   1.638435  -1.486811
# 2000-01-03   0.504765  -1.198235   2.955597  -1.257166
# 2000-01-04   0.803148  -1.282076   5.966986  -2.501552
# 2000-01-05   1.023462  -0.844092   5.671452  -2.672713
# ...               ...        ...        ...        ...
# 2002-09-22  34.205367 -50.416431 -41.939157 -28.881550
# 2002-09-23  34.047809 -50.561633 -40.745521 -31.034942
# 2002-09-24  34.394324 -50.846630 -40.560689 -30.859070
# 2002-09-25  33.374786 -49.925112 -40.039959 -31.770444
# 2002-09-26  32.796673 -50.321773 -39.319165 -31.097754
#
# [1000 rows x 4 columns]

# %% [markdown]
# - Excel

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0          A          B          C          D
# 0   2000-01-01   1.144381  -0.002242   0.158862  -0.240616
# 1   2000-01-02   0.384763   0.033501   1.638435  -1.486811
# 2   2000-01-03   0.504765  -1.198235   2.955597  -1.257166
# 3   2000-01-04   0.803148  -1.282076   5.966986  -2.501552
# 4   2000-01-05   1.023462  -0.844092   5.671452  -2.672713
# ..         ...        ...        ...        ...        ...
# 995 2002-09-22  34.205367 -50.416431 -41.939157 -28.881550
# 996 2002-09-23  34.047809 -50.561633 -40.745521 -31.034942
# 997 2002-09-24  34.394324 -50.846630 -40.560689 -30.859070
# 998 2002-09-25  33.374786 -49.925112 -40.039959 -31.770444
# 999 2002-09-26  32.796673 -50.321773 -39.319165 -31.097754
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 13. Gotchas (잡았다!)
# - 예외 상황

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-5c782b38cd2f> in <module>()
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# 이러한 경우에는 any(), all(), empty 등을 사용해서 무엇을 원하는지를 선택 (반영)해주어야

if pd.Series([False, True, False])is not None:
      print("I was not None")
# Out:
# I was not None

# %% [markdown]
# # 10 minutes to pandas
#
# - https://pandas.pydata.org/docs/user_guide/10min.html

# %%
import numpy as np

# %%
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.447205 -1.415499  0.415436 -0.419206
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465
# 2013-01-06  1.163262 -0.684634  0.544150  0.061399

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.447205 -1.415499  0.415436 -0.419206
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465
# 2013-01-06  1.163262 -0.684634  0.544150  0.061399

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.44720512, -1.41549865,  0.41543633, -0.41920573],
#        [ 0.07605415, -0.88163417,  0.71470136,  0.9685111 ],
#        [ 1.22043125, -0.61193578, -0.00186209, -0.8054424 ],
#        [ 0.1797202 , -0.35361541,  0.14868621, -0.9411048 ],
#        [ 0.01748984, -1.02489119,  0.06256576, -1.65746522],
#        [ 1.16326219, -0.6846343 ,  0.54415037,  0.06139875]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %% [markdown]
# DataFrame.to_numpy() does not include the index or column labels in the output.

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.368292 -0.828702  0.313946 -0.465551
# std    0.673376  0.368530  0.287797  0.905394
# min   -0.447205 -1.415499 -0.001862 -1.657465
# 25%    0.032131 -0.989077  0.084096 -0.907189
# 50%    0.127887 -0.783134  0.282061 -0.612324
# 75%    0.917377 -0.630110  0.511972 -0.058752
# max    1.220431 -0.353615  0.714701  0.968511

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.447205    0.076054    1.220431    0.179720    0.017490    1.163262
# B   -1.415499   -0.881634   -0.611936   -0.353615   -1.024891   -0.684634
# C    0.415436    0.714701   -0.001862    0.148686    0.062566    0.544150
# D   -0.419206    0.968511   -0.805442   -0.941105   -1.657465    0.061399

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.419206  0.415436 -1.415499 -0.447205
# 2013-01-02  0.968511  0.714701 -0.881634  0.076054
# 2013-01-03 -0.805442 -0.001862 -0.611936  1.220431
# 2013-01-04 -0.941105  0.148686 -0.353615  0.179720
# 2013-01-05 -1.657465  0.062566 -1.024891  0.017490
# 2013-01-06  0.061399  0.544150 -0.684634  1.163262

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-01 -0.447205 -1.415499  0.415436 -0.419206
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-06  1.163262 -0.684634  0.544150  0.061399
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105

# %%
df["A"]
# Out:
# 2013-01-01   -0.447205
# 2013-01-02    0.076054
# 2013-01-03    1.220431
# 2013-01-04    0.179720
# 2013-01-05    0.017490
# 2013-01-06    1.163262
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.447205 -1.415499  0.415436 -0.419206
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105

# %%
df.loc[dates[0]]
# Out:
# A   -0.447205
# B   -1.415499
# C    0.415436
# D   -0.419206
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.447205 -1.415499
# 2013-01-02  0.076054 -0.881634
# 2013-01-03  1.220431 -0.611936
# 2013-01-04  0.179720 -0.353615
# 2013-01-05  0.017490 -1.024891
# 2013-01-06  1.163262 -0.684634

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02  0.076054 -0.881634
# 2013-01-03  1.220431 -0.611936
# 2013-01-04  0.179720 -0.353615

# %%
df.loc["20130102", ["A", "B"]]
# Out:
# A    0.076054
# B   -0.881634
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# -0.4472051226750298

# %%
df.at[dates[0], "A"]
# Out:
# -0.4472051226750298

# %%
df.iloc[3]
# Out:
# A    0.179720
# B   -0.353615
# C    0.148686
# D   -0.941105
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                   A         B
# 2013-01-04  0.17972 -0.353615
# 2013-01-05  0.01749 -1.024891

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  0.076054  0.714701
# 2013-01-03  1.220431 -0.001862
# 2013-01-05  0.017490  0.062566

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.415499  0.415436
# 2013-01-02 -0.881634  0.714701
# 2013-01-03 -0.611936 -0.001862
# 2013-01-04 -0.353615  0.148686
# 2013-01-05 -1.024891  0.062566
# 2013-01-06 -0.684634  0.544150

# %%
df.iloc[1, 1]
# Out:
# -0.8816341654230094

# %%
df.iat[1, 1]
# Out:
# -0.8816341654230094

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465
# 2013-01-06  1.163262 -0.684634  0.544150  0.061399

# %%
df[df > 0]
# Out:
#                    A   B         C         D
# 2013-01-01       NaN NaN  0.415436       NaN
# 2013-01-02  0.076054 NaN  0.714701  0.968511
# 2013-01-03  1.220431 NaN       NaN       NaN
# 2013-01-04  0.179720 NaN  0.148686       NaN
# 2013-01-05  0.017490 NaN  0.062566       NaN
# 2013-01-06  1.163262 NaN  0.544150  0.061399

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.447205 -1.415499  0.415436 -0.419206    one
# 2013-01-02  0.076054 -0.881634  0.714701  0.968511    one
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442    two
# 2013-01-04  0.179720 -0.353615  0.148686 -0.941105  three
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465   four
# 2013-01-06  1.163262 -0.684634  0.544150  0.061399  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  1.220431 -0.611936 -0.001862 -0.805442   two
# 2013-01-05  0.017490 -1.024891  0.062566 -1.657465  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, "D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  0.415436  5  NaN
# 2013-01-02  0.076054 -0.881634  0.714701  5  1.0
# 2013-01-03  1.220431 -0.611936 -0.001862  5  2.0
# 2013-01-04  0.179720 -0.353615  0.148686  5  3.0
# 2013-01-05  0.017490 -1.024891  0.062566  5  4.0
# 2013-01-06  1.163262 -0.684634  0.544150  5  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.415436 -5  NaN
# 2013-01-02 -0.076054 -0.881634 -0.714701 -5 -1.0
# 2013-01-03 -1.220431 -0.611936 -0.001862 -5 -2.0
# 2013-01-04 -0.179720 -0.353615 -0.148686 -5 -3.0
# 2013-01-05 -0.017490 -1.024891 -0.062566 -5 -4.0
# 2013-01-06 -1.163262 -0.684634 -0.544150 -5 -5.0

# %% [markdown]
# ## Missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.415436  5  NaN  1.0
# 2013-01-02  0.076054 -0.881634  0.714701  5  1.0  1.0
# 2013-01-03  1.220431 -0.611936 -0.001862  5  2.0  NaN
# 2013-01-04  0.179720 -0.353615  0.148686  5  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D    F    E
# 2013-01-02  0.076054 -0.881634  0.714701  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.415436  5  5.0  1.0
# 2013-01-02  0.076054 -0.881634  0.714701  5  1.0  1.0
# 2013-01-03  1.220431 -0.611936 -0.001862  5  2.0  5.0
# 2013-01-04  0.179720 -0.353615  0.148686  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %%
df.mean()
# Out:
# A    0.442826
# B   -0.592785
# C    0.313946
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.353859
# 2013-01-02    1.181824
# 2013-01-03    1.521327
# 2013-01-04    1.594958
# 2013-01-05    1.611033
# 2013-01-06    2.204556
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03  0.220431 -1.611936 -1.001862  4.0  1.0
# 2013-01-04 -2.820280 -3.353615 -2.851314  2.0  0.0
# 2013-01-05 -4.982510 -6.024891 -4.937434  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ## Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.415436   5   NaN
# 2013-01-02  0.076054 -0.881634  1.130138  10   1.0
# 2013-01-03  1.296485 -1.493570  1.128276  15   3.0
# 2013-01-04  1.476206 -1.847185  1.276962  20   6.0
# 2013-01-05  1.493695 -2.872077  1.339528  25  10.0
# 2013-01-06  2.656958 -3.556711  1.883678  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.220431
# B    1.024891
# C    0.716563
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ## Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    4
# 1    1
# 2    3
# 3    5
# 4    1
# 5    5
# 6    5
# 7    2
# 8    5
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 5    4
# 4    2
# 1    2
# 3    1
# 2    1
# dtype: int64

# %% [markdown]
# ## String Methods

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.141558 -1.172255 -1.527109  0.411425
# 1  0.527861  1.177782 -0.509060  0.228392
# 2  0.959363 -1.420044 -2.854401 -0.698306
# 3 -1.999973  1.259134 -1.212511 -0.157609
# 4 -1.830625 -0.992132  0.617988  1.524316
# 5  0.036304  1.537439  1.443501  1.033337
# 6 -0.477727  0.403691  0.117763 -0.228043
# 7  0.118842  0.384570 -0.369866  0.988675
# 8 -0.670941 -0.801663  0.593094  0.143780
# 9 -0.428165  0.832511  0.657365 -0.522456

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.141558 -1.172255 -1.527109  0.411425
# 1  0.527861  1.177782 -0.509060  0.228392
# 2  0.959363 -1.420044 -2.854401 -0.698306
# 3 -1.999973  1.259134 -1.212511 -0.157609
# 4 -1.830625 -0.992132  0.617988  1.524316
# 5  0.036304  1.537439  1.443501  1.033337
# 6 -0.477727  0.403691  0.117763 -0.228043
# 7  0.118842  0.384570 -0.369866  0.988675
# 8 -0.670941 -0.801663  0.593094  0.143780
# 9 -0.428165  0.832511  0.657365 -0.522456

# %% [markdown]
# ## Join

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %% [markdown]
# ## Grouping

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one  0.914723  0.133535
# 1  bar    one -0.789137  0.443513
# 2  foo    two  1.516614  0.343236
# 3  bar  three -2.799557  0.695185
# 4  foo    two  0.318044  0.645327
# 5  bar    two -0.229514 -0.574477
# 6  foo    one -0.489881 -0.066461
# 7  foo  three -0.684367 -1.640396

# %%
df.groupby("A").sum()
# Out:
#             C        D
# A
# bar -3.818208  0.56422
# foo  1.575134 -0.58476

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.789137  0.443513
#     three -2.799557  0.695185
#     two   -0.229514 -0.574477
# foo one    0.424842  0.067074
#     three -0.684367 -1.640396
#     two    1.834658  0.988562

# %% [markdown]
# ## Reshaping

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.677550  0.937141
#       two     0.309970 -0.631782
# baz   one     1.706121  0.006556
#       two     2.202712 -0.398200

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.677550
#                B    0.937141
#        two     A    0.309970
#                B   -0.631782
# baz    one     A    1.706121
#                B    0.006556
#        two     A    2.202712
#                B   -0.398200
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.677550  0.937141
#       two     0.309970 -0.631782
# baz   one     1.706121  0.006556
#       two     2.202712 -0.398200

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.677550  0.309970
#       B  0.937141 -0.631782
# baz   A  1.706121  2.202712
#       B  0.006556 -0.398200

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.677550  1.706121
#        B  0.937141  0.006556
# two    A  0.309970  2.202712
#        B -0.631782 -0.398200

# %% [markdown]
# - Pivot tables

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.907310  2.035384
# 1     one  B  foo -1.041839  0.913881
# 2     two  C  foo  0.350662 -0.238221
# 3   three  A  bar -1.037410  0.886584
# 4     one  B  bar  1.259049 -0.273548
# 5     one  C  bar -0.014484 -2.130796
# 6     two  A  foo -1.032321  0.263691
# 7   three  B  foo -0.106302 -2.442493
# 8     one  C  foo -0.534058  0.535382
# 9     one  A  bar  1.632226 -0.102549
# 10    two  B  bar -1.342476 -1.236502
# 11  three  C  bar -0.971900  0.019946

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  1.632226  0.907310
#       B  1.259049 -1.041839
#       C -0.014484 -0.534058
# three A -1.037410       NaN
#       B       NaN -0.106302
#       C -0.971900       NaN
# two   A       NaN -1.032321
#       B -1.342476       NaN
#       C       NaN  0.350662

# %% [markdown]
# - Time series

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2012-01-01    23766
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -1.232794
# 2012-03-07    1.736319
# 2012-03-08    0.551561
# 2012-03-09    1.098254
# 2012-03-10    0.298657
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -1.232794
# 2012-03-07 00:00:00+00:00    1.736319
# 2012-03-08 00:00:00+00:00    0.551561
# 2012-03-09 00:00:00+00:00    1.098254
# 2012-03-10 00:00:00+00:00    0.298657
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00   -1.232794
# 2012-03-06 19:00:00-05:00    1.736319
# 2012-03-07 19:00:00-05:00    0.551561
# 2012-03-08 19:00:00-05:00    1.098254
# 2012-03-09 19:00:00-05:00    0.298657
# Freq: D, dtype: float64

# %%
rng = pd.date_range("1/1/2012", periods=5, freq="M")
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31   -0.039340
# 2012-02-29    2.686117
# 2012-03-31   -0.338684
# 2012-04-30   -0.890984
# 2012-05-31   -0.171688
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01   -0.039340
# 2012-02    2.686117
# 2012-03   -0.338684
# 2012-04   -0.890984
# 2012-05   -0.171688
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.039340
# 2012-02-01    2.686117
# 2012-03-01   -0.338684
# 2012-04-01   -0.890984
# 2012-05-01   -0.171688
# Freq: MS, dtype: float64

# %%
prng = pd.period_range("1990Q1", "2000Q4", freq="Q-NOV")
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts.head()
# Out:
# 1990-03-01 09:00   -1.399344
# 1990-06-01 09:00    1.375604
# 1990-09-01 09:00   -0.773417
# 1990-12-01 09:00    0.146093
# 1991-03-01 09:00    0.293528
# Freq: H, dtype: float64

# %% [markdown]
# ## Categoricals

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
plt.show();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df = df.cumsum()
plt.figure();

# %%
df.plot();

# %% [markdown]
# ## Getting data in/out
# - CSV

# %%
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#      Unnamed: 0             A             B             C             D
# 0    2000-01-01      1.403857      1.291987      0.189668      0.550260
# 1    2000-01-02      2.142990      2.683977     -0.026091      1.631917
# 2    2000-01-03      1.112196      2.893101     -0.856500      3.914641
# 3    2000-01-04     -0.175124      3.797215     -2.062722      7.230985
# 4    2000-01-05     -0.813377      5.305872     -2.280351     10.246125
# ..          ...           ...           ...           ...           ...
# 995  2002-09-22  16030.984107  44036.982136  17579.948397  16120.676004
# 996  2002-09-23  16045.707309  44082.871135  17605.991556  16161.002194
# 997  2002-09-24  16061.779545  44127.478638  17632.742613  16200.411242
# 998  2002-09-25  16077.777389  44173.084247  17658.208921  16240.003989
# 999  2002-09-26  16094.258223  44218.354559  17683.503629  16281.691211
#
# [1000 rows x 5 columns]

# %% [markdown]
# - HDF5

# %%
df.to_hdf("foo.h5", "df")

# %%
pd.read_hdf("foo.h5", "df")
# Out:
#                        A             B             C             D
# 2000-01-01      1.403857      1.291987      0.189668      0.550260
# 2000-01-02      2.142990      2.683977     -0.026091      1.631917
# 2000-01-03      1.112196      2.893101     -0.856500      3.914641
# 2000-01-04     -0.175124      3.797215     -2.062722      7.230985
# 2000-01-05     -0.813377      5.305872     -2.280351     10.246125
# ...                  ...           ...           ...           ...
# 2002-09-22  16030.984107  44036.982136  17579.948397  16120.676004
# 2002-09-23  16045.707309  44082.871135  17605.991556  16161.002194
# 2002-09-24  16061.779545  44127.478638  17632.742613  16200.411242
# 2002-09-25  16077.777389  44173.084247  17658.208921  16240.003989
# 2002-09-26  16094.258223  44218.354559  17683.503629  16281.691211
#
# [1000 rows x 4 columns]

# %% [markdown]
# - Excel

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#     Unnamed: 0             A             B             C             D
# 0   2000-01-01      1.403857      1.291987      0.189668      0.550260
# 1   2000-01-02      2.142990      2.683977     -0.026091      1.631917
# 2   2000-01-03      1.112196      2.893101     -0.856500      3.914641
# 3   2000-01-04     -0.175124      3.797215     -2.062722      7.230985
# 4   2000-01-05     -0.813377      5.305872     -2.280351     10.246125
# ..         ...           ...           ...           ...           ...
# 995 2002-09-22  16030.984107  44036.982136  17579.948397  16120.676004
# 996 2002-09-23  16045.707309  44082.871135  17605.991556  16161.002194
# 997 2002-09-24  16061.779545  44127.478638  17632.742613  16200.411242
# 998 2002-09-25  16077.777389  44173.084247  17658.208921  16240.003989
# 999 2002-09-26  16094.258223  44218.354559  17683.503629  16281.691211
#
# [1000 rows x 5 columns]
